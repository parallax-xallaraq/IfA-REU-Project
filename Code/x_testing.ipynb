# %%
# plotting 
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.pyplot as plt
import matplotlib as mpl
# data 
import numpy as np
# local 
import v2_AGN_DataAndPlotting as adp

# %%
def PlotIRAC_one():
    # set default style preferences 
    adp.SetStyle() 

    # get plot axis
    ax = plt.gca()

    plt.scatter( adp.template_AGN_z1[0], adp.template_AGN_z1[1], marker="X")
    plt.scatter( adp.template_Sbc_z1[0], adp.template_Sbc_z1[1], marker="o")

    # plot wedge shape 
    adp.PlotDonleyWedge()

    # format
    plt.axis([-0.25,1.25,-0.25,1.25]) 

    # axis 
    ax = plt.gca()
    ax.set_aspect('equal')
    ax.set_adjustable('box')
    ax.set_xticks([-0.75,-0.50,-0.25,0.0,0.25,0.50,0.75,1.0,1.25])
    ax.set_yticks([-0.75,-0.50,-0.25,0.0,0.25,0.50,0.75,1.0,1.25])
    ax.xaxis.set_minor_locator(AutoMinorLocator(2))
    ax.yaxis.set_minor_locator(AutoMinorLocator(2))
    
    # show plot 
    plt.show()


PlotIRAC_one()
